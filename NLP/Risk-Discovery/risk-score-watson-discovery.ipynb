# %%
#import lib

import csv
import json
import tempfile
from ibm_watson import DiscoveryV2
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
#import IBM API key and service URL from ibm-credentials.env

import os
from dotenv import load_dotenv
load_dotenv('ibm-discovery-credentials.env')
API_KEY = os.getenv('DISCOVERY_APIKEY')
URL=os.getenv('DISCOVERY_URL')

# %%
#load API key

authenticator = IAMAuthenticator(API_KEY)
discovery = DiscoveryV2(
    version='2020-08-30',
    authenticator=authenticator
)

discovery.set_service_url(URL)
#discovery.set_disable_ssl_verification(True)

# %%
#constants

PROJECT_ID='daa312d8-8893-4782-970d-5aa98e368399'
COLLECTION_SIZE=263
RISK_SCORE_INIT=0

# %%
#convert ad listing csv data to list
### the same data have been uploaded to and processed by watson Discovery service currently under use ###

data_list=[]

title_arr=[]
ad_id_arr=[]
country_arr=[]
sector_arr=[]
date_arr=[]
risk_arr=[]

with open("locanto_demo.csv",newline='',encoding='utf-8') as f:
    reader=csv.reader(f)
    boolVal = 0
    for row in reader:
        data_list.append(row)
        temp = str(row).split(',')
        while boolVal == 1:
                title_arr.append(temp[0])
                ad_id_arr.append(temp[1])
                country_arr.append(temp[len(temp)-3])
                sector_arr.append(temp[len(temp)-1])
                date_arr.append(temp[len(temp)-2])
                risk_arr.append(RISK_SCORE_INIT)
                                
                boolVal = 0
        boolVal = 1
#print(len(ad_id_arr))

# %%
#format ads list into json

line=1
print("{\"ads\": [")
while line < len(data_list):
    # take the specific string values out of the array and remove unwanted characters
    unwantedChars = "\"][\'"
    temp_title = title_arr[line-1]
    temp_ad_id = ad_id_arr[line-1].replace("'","")
    temp_country = country_arr[line-1].replace("'","")
    temp_sector = sector_arr[line-1].replace("'","")
    temp_date=date_arr[line-1].replace("'","")
    for unwantedChar in unwantedChars:
        temp_title = temp_title.replace(unwantedChar, "")
        temp_country = temp_country.replace(unwantedChar,"")
        temp_sector = temp_sector.replace(unwantedChar,"")
    print(f"{'{'}\n")
    print(f" \"{'Job_title'}\": {'{'}\n   \"{'title'}\": \"{temp_title}\"\n {'}'},\n")
    print(f" \"{'Ad_id'}\": {'{'}\n   \"{'id'}\": \"{temp_ad_id}\"\n {'}'},\n")
    print(f" \"{'Country'}\": {'{'}\n   \"{'country'}\": \"{temp_country}\"\n {'}'},\n")
    print(f" \"{'Sector'}\": {'{'}\n   \"{'sector'}\": \"{temp_sector}\"\n {'}'},\n")
    print(f" \"{'Date'}\": {'{'}\n   \"{'date'}\": \"{temp_date}\"\n {'}'},\n")
    print(f" \"{'Risk_score'}\": {'{'}\n   \"{'risk'}\": \"{RISK_SCORE_INIT}\"\n {'}'}\n")
    str = (('}', '},') [line < (len(data_list)-1)])
    print(str)
    line = line + 1
print("]}")

### save output as 'locanto_demo_formatted.json' ###
# Out:
# {"ads": [
# {
#
#  "Job_title": {
#    "title": "Customer Service Assistant - Jameson Visitor Centre …"
#  },
#
#  "Ad_id": {
#    "id": " 5499952319"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Specialist - Dutch"
#  },
#
#  "Ad_id": {
#    "id": " 5495340327"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Overnight Customer Assistant - Ballywaltrim Lane"
#  },
#
#  "Ad_id": {
#    "id": " Bray"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Air Logistics Customer Care Expert"
#  },
#
#  "Ad_id": {
#    "id": " 5495353802"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Outbound Telesales"
#  },
#
#  "Ad_id": {
#    "id": " 5495307329"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495299953"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Business Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495346560"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Product Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " Small & Medium Businesses"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5496303455"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Business Support Specialist (Site Focal)"
#  },
#
#  "Ad_id": {
#    "id": " 5495336057"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Advisor"
#  },
#
#  "Ad_id": {
#    "id": " 5495297827"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Executive – French"
#  },
#
#  "Ad_id": {
#    "id": " 5495324729"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495338942"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Agent"
#  },
#
#  "Ad_id": {
#    "id": " 5495299390"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Representative - German Speaker"
#  },
#
#  "Ad_id": {
#    "id": " 5495277692"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German Junior Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495332244"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495299093"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Print Customer Care Admin"
#  },
#
#  "Ad_id": {
#    "id": " 5495331217"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support / Sales Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495274221"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Service Excellence & Stakeholder Engagement Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495296761"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant -M11 Gorey"
#  },
#
#  "Ad_id": {
#    "id": " Co"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495345072"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Sales & Service Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495297656"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Technical Support Specialist with Japanese - Night Shift"
#  },
#
#  "Ad_id": {
#    "id": " 5495330430"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant (Permanent)"
#  },
#
#  "Ad_id": {
#    "id": " Flexible Shifts"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support"
#  },
#
#  "Ad_id": {
#    "id": " 5495303643"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Team Lead"
#  },
#
#  "Ad_id": {
#    "id": " 5495353823"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Adoption Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495339742"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Operational Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495345677"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Contact Representative- First Homes Scheme"
#  },
#
#  "Ad_id": {
#    "id": " 5495292123"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Process Support Specialist - Carlow"
#  },
#
#  "Ad_id": {
#    "id": " 5495275665"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support with Portuguese Fluency"
#  },
#
#  "Ad_id": {
#    "id": " 5495314903"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Coordinator – Nordic Languages"
#  },
#
#  "Ad_id": {
#    "id": " 5495343193"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Agent"
#  },
#
#  "Ad_id": {
#    "id": " 5495301652"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495347846"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Norwegian Customer Success Coordinator"
#  },
#
#  "Ad_id": {
#    "id": " 5495339904"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Danish + Norwegian- Customer Success Coordinators"
#  },
#
#  "Ad_id": {
#    "id": " 5495327963"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "RCC Senior Customer Service Specialist - German"
#  },
#
#  "Ad_id": {
#    "id": " 5495346404"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Italian Customer Support Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495337160"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Internal Laboratory Sales Customer Service Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495300944"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Services/Sales Agents"
#  },
#
#  "Ad_id": {
#    "id": " 5495284348"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " Night"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant (Permanent)"
#  },
#
#  "Ad_id": {
#    "id": " Flexible Shifts"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Bilingual Customer Support Representative (German Speaking)"
#  },
#
#  "Ad_id": {
#    "id": " 5495345255"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Retail Customer Sales & Service Advisor"
#  },
#
#  "Ad_id": {
#    "id": " 5495294635"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service"
#  },
#
#  "Ad_id": {
#    "id": " 5495278437"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Executive - Dublin 24 - -32k"
#  },
#
#  "Ad_id": {
#    "id": " 5495354842"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Head of Customer Service"
#  },
#
#  "Ad_id": {
#    "id": " 5495321317"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant - Middleton"
#  },
#
#  "Ad_id": {
#    "id": " Co. Cork"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " Azure"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Expert"
#  },
#
#  "Ad_id": {
#    "id": " 5495352028"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Process Support Specialist (Biotech) Carlow"
#  },
#
#  "Ad_id": {
#    "id": " 5495276953"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Exports Customer Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5496304261"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Manager DATA Centre Services"
#  },
#
#  "Ad_id": {
#    "id": " 5495345253"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Telesales Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495315352"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "B2B Customer Support Representative - French&Italian German"
#  },
#
#  "Ad_id": {
#    "id": " 5495339193"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German Customer Service Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5496304794"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Expert Swedish OR Norwegian WFH in Ireland"
#  },
#
#  "Ad_id": {
#    "id": " 5495306040"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "IT Technical Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495344827"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Expert - Norwegian WFH"
#  },
#
#  "Ad_id": {
#    "id": " 5495327823"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Manager - MES/Software - Dublin - €75K"
#  },
#
#  "Ad_id": {
#    "id": " 5495300682"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Meetings Services Associate"
#  },
#
#  "Ad_id": {
#    "id": " 5495280994"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Services Support"
#  },
#
#  "Ad_id": {
#    "id": " 5495285670"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Specialist (German Speaking)"
#  },
#
#  "Ad_id": {
#    "id": " 5495347558"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Onboarding Strategist"
#  },
#
#  "Ad_id": {
#    "id": " Global Customer Solutions"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Team Lead"
#  },
#
#  "Ad_id": {
#    "id": " Customer Service"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Onboarding & Customer Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495349613"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "CSA Supervisor"
#  },
#
#  "Ad_id": {
#    "id": " 5495309404"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support with English Fluency"
#  },
#
#  "Ad_id": {
#    "id": " 5495314902"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495287007"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant (Permanent)"
#  },
#
#  "Ad_id": {
#    "id": " Flexible Shifts"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "CSA Estimator"
#  },
#
#  "Ad_id": {
#    "id": " Dublin"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Dispatch Supervisor"
#  },
#
#  "Ad_id": {
#    "id": " 5495287484"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Expert Danish"
#  },
#
#  "Ad_id": {
#    "id": " 5495335925"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Coordinator"
#  },
#
#  "Ad_id": {
#    "id": " 5495343026"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Team Lead"
#  },
#
#  "Ad_id": {
#    "id": " 5495325181"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495330575"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Quality Business Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495331237"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495322502"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Technical Support Associate with Russian"
#  },
#
#  "Ad_id": {
#    "id": " 5495348992"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Experienced Customer Service Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495304355"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Engineering Manager - Customer Platform"
#  },
#
#  "Ad_id": {
#    "id": " 5495325190"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Technical Support Associate Clinical Research/Healthcare …"
#  },
#
#  "Ad_id": {
#    "id": " 5495340619"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German Customer Service Representative - Galway - Hybrid"
#  },
#
#  "Ad_id": {
#    "id": " 5495316897"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Sea Logistics Customer Care Expert"
#  },
#
#  "Ad_id": {
#    "id": " 5495287182"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Admin"
#  },
#
#  "Ad_id": {
#    "id": " 5495275237"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Product Support Specialist - German Speaking"
#  },
#
#  "Ad_id": {
#    "id": " 5495340953"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Director of Customer Operations - Irish SME - Services Industry"
#  },
#
#  "Ad_id": {
#    "id": " 5495352355"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Business Support Specialist (Site Focal)"
#  },
#
#  "Ad_id": {
#    "id": " 5495354247"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Specialist 6-Month FTC"
#  },
#
#  "Ad_id": {
#    "id": " 5495348703"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Management Executive - Gas Networks Ireland"
#  },
#
#  "Ad_id": {
#    "id": " 5495299728"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Warehouse Operator - Dispatch"
#  },
#
#  "Ad_id": {
#    "id": " 5495289770"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Czech Customer Support Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495331804"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "DUTCH Customer support executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495341807"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495351156"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Technical Support Associate - MDR"
#  },
#
#  "Ad_id": {
#    "id": " 5495313247"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant (Fixed"
#  },
#
#  "Ad_id": {
#    "id": " Term)"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Telesales & Customer Service Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495277454"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "French speaker - Business/Finance/Accounting or Customer …"
#  },
#
#  "Ad_id": {
#    "id": " 5495330421"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495345368"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Operations Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495329945"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant - Garryspillane"
#  },
#
#  "Ad_id": {
#    "id": " Co. Limerick"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Content Reviewer - German Speaking"
#  },
#
#  "Ad_id": {
#    "id": " 5495289381"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Experience Specialist (Night-Shift)"
#  },
#
#  "Ad_id": {
#    "id": " 5495277452"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Branch Customer Service Advisor"
#  },
#
#  "Ad_id": {
#    "id": " 5495313119"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Head of CSR"
#  },
#
#  "Ad_id": {
#    "id": " 5495324912"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Clinical Support Specialist - Leinster"
#  },
#
#  "Ad_id": {
#    "id": " 5495345700"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Agent (Telesales)"
#  },
#
#  "Ad_id": {
#    "id": " 5495279972"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Switcher Support Specialist - Galway"
#  },
#
#  "Ad_id": {
#    "id": " Mayo"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Operations Team Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495317434"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Collections Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495302778"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Technical Support Specialist with French"
#  },
#
#  "Ad_id": {
#    "id": " 5495334641"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Dispatch"
#  },
#
#  "Ad_id": {
#    "id": " 5495301790"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Bilingual Customer Onboarding Specialist - Spanish and English"
#  },
#
#  "Ad_id": {
#    "id": " 5495341471"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "IT Support & Applications Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495274818"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German - Customer Success Associate"
#  },
#
#  "Ad_id": {
#    "id": " 5495340190"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Senior QA Specialist - Technical Support Packaging - Dublin …"
#  },
#
#  "Ad_id": {
#    "id": " 5495291882"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Spare Parts Advisor / Customer Support"
#  },
#
#  "Ad_id": {
#    "id": " 5495341432"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Application Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495317604"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Fluent in Dutch- Customer Service Executive required!"
#  },
#
#  "Ad_id": {
#    "id": " 5495354107"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager (DACH) Dublin"
#  },
#
#  "Ad_id": {
#    "id": " Ireland"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Office Coordinator"
#  },
#
#  "Ad_id": {
#    "id": " 5495310003"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Executive - Russian Language"
#  },
#
#  "Ad_id": {
#    "id": " 5495330777"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Agent"
#  },
#
#  "Ad_id": {
#    "id": " 5495278472"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Executive – German"
#  },
#
#  "Ad_id": {
#    "id": " 5495329359"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Business Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495290448"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "IT Technical Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5496303979"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German Customer Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495335504"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Multilingual Senior Technical Support Specialist ? Service …"
#  },
#
#  "Ad_id": {
#    "id": " 5495342465"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495307334"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "IT Technical Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495355252"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Associate (Spanish Speaker)"
#  },
#
#  "Ad_id": {
#    "id": " 5495335917"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Technical Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495347128"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Client Success Agency Representative Dutch - Dublin (€36-49K)"
#  },
#
#  "Ad_id": {
#    "id": " 5495299737"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Advisor- Life & Pension Contact Centre"
#  },
#
#  "Ad_id": {
#    "id": " 5495303353"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager Galway"
#  },
#
#  "Ad_id": {
#    "id": " Ireland"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer care expert- Nordic language"
#  },
#
#  "Ad_id": {
#    "id": " Dutch or German …"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Billing Customer Service Representative - French language …"
#  },
#
#  "Ad_id": {
#    "id": " 5495276518"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495334565"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495334705"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Assistant Vice President"
#  },
#
#  "Ad_id": {
#    "id": " Systems Support and Development …"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " Emerging"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Expert with DANISH"
#  },
#
#  "Ad_id": {
#    "id": " 5495334939"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Senior Manager Customer Experience Vision Care"
#  },
#
#  "Ad_id": {
#    "id": " 5495336830"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Engineer - semiconductor"
#  },
#
#  "Ad_id": {
#    "id": " 5495303280"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Advisor"
#  },
#
#  "Ad_id": {
#    "id": " 4841438055"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Services Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495279523"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495278111"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Swedish Customer Care Executive - Tech company"
#  },
#
#  "Ad_id": {
#    "id": " 5495349455"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "CSA Project Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495345374"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "B2B Customer Support Representative - French&Italian/German"
#  },
#
#  "Ad_id": {
#    "id": " 5495352004"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German Customer Service Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495330384"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Bilingual Customer Experience Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495300941"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "CSA Project Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495279096"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Account Switching Support Specialist - Banking"
#  },
#
#  "Ad_id": {
#    "id": " 5495311370"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Global Customer Lifecycle Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495328370"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Executive (Polish)"
#  },
#
#  "Ad_id": {
#    "id": " 5495343654"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Global Customer Operations Manager (m/f/d)"
#  },
#
#  "Ad_id": {
#    "id": " 5495334136"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant - Grange Rd"
#  },
#
#  "Ad_id": {
#    "id": " Rathfarnham"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "RCC Senior Customer Service Specialist - German"
#  },
#
#  "Ad_id": {
#    "id": " 5495345236"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
# ...
#  },
#
#  "Ad_id": {
#    "id": " 5495353397"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Manager"
#  },
#
#  "Ad_id": {
#    "id": " 5495332618"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German +B2 / Customer Experience Associate"
#  },
#
#  "Ad_id": {
#    "id": " 5495345671"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Danish Customer Care Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495322974"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German-speaking Customer service agent Hybrid"
#  },
#
#  "Ad_id": {
#    "id": " 5495274124"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Call Centre Agent - Frank Keane Volkswagen"
#  },
#
#  "Ad_id": {
#    "id": " Deansgrange"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Specialist | Santry | 6-Month FTC"
#  },
#
#  "Ad_id": {
#    "id": " 5495349583"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Support Specialist- SDK support"
#  },
#
#  "Ad_id": {
#    "id": " 5495337680"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant - Fonthill Retail Park"
#  },
#
#  "Ad_id": {
#    "id": " 5495304379"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Representative"
#  },
#
#  "Ad_id": {
#    "id": " 5495346098"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Sales & Call Centre Lead"
#  },
#
#  "Ad_id": {
#    "id": " 5495324310"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Senior Manager"
#  },
#
#  "Ad_id": {
#    "id": " Application Technical Support"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Application Support - Technical Operations Specialist (TOPS)"
#  },
#
#  "Ad_id": {
#    "id": " 5495336269"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Account Switching Support Specialist - Banking"
#  },
#
#  "Ad_id": {
#    "id": " 5495313805"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer service executive - German"
#  },
#
#  "Ad_id": {
#    "id": " 5495320459"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German Customer Service Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495348789"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Swedish Customer Success Coordinator"
#  },
#
#  "Ad_id": {
#    "id": " 5495344636"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Management Executive - Gas Networks Ireland"
#  },
#
#  "Ad_id": {
#    "id": " 5495348439"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495332611"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support / Chat Specialist – Russian - Day Shift"
#  },
#
#  "Ad_id": {
#    "id": " 5495349178"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Senior Customer Service / Sales Order Processor"
#  },
#
#  "Ad_id": {
#    "id": " 5495306329"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Management (AIBMS)"
#  },
#
#  "Ad_id": {
#    "id": " 5495297634"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Success Engineer"
#  },
#
#  "Ad_id": {
#    "id": " 5495341983"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German team lead- customer care team"
#  },
#
#  "Ad_id": {
#    "id": " 5495320586"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Software Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495276729"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant (Permanent)"
#  },
#
#  "Ad_id": {
#    "id": " Flexible Shifts"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Head of CSR"
#  },
#
#  "Ad_id": {
#    "id": " 5495355856"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Representative - French"
#  },
#
#  "Ad_id": {
#    "id": " 5495310684"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service/Telesales Executive - Full Time Hours"
#  },
#
#  "Ad_id": {
#    "id": " 5495297819"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Principal Azure Customer Engineer"
#  },
#
#  "Ad_id": {
#    "id": " 5495356302"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Commercial Customer Success Representative - German"
#  },
#
#  "Ad_id": {
#    "id": " 5495351867"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "French Speaker - Business/Finance background or previous …"
#  },
#
#  "Ad_id": {
#    "id": " 5495342138"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Warehouse Customer Support & Administration"
#  },
#
#  "Ad_id": {
#    "id": " 5495293024"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Agent - Revenue Protection team"
#  },
#
#  "Ad_id": {
#    "id": " 5495279411"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Polish"
#  },
#
#  "Ad_id": {
#    "id": " Russian"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Representative with German OR Spanish OR …"
#  },
#
#  "Ad_id": {
#    "id": " 5495314905"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Advisor"
#  },
#
#  "Ad_id": {
#    "id": " 5495299842"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant (Permanent)"
#  },
#
#  "Ad_id": {
#    "id": " Flexible Shifts"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Telesales Consultant - Website Development"
#  },
#
#  "Ad_id": {
#    "id": " 5496303389"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "German Customer Support Associate – Galway"
#  },
#
#  "Ad_id": {
#    "id": " 5495342468"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Executive"
#  },
#
#  "Ad_id": {
#    "id": " 5495296971"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Food Customer Assistant - Middleton"
#  },
#
#  "Ad_id": {
#    "id": " Co. Cork"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Assistant - Blessington"
#  },
#
#  "Ad_id": {
#    "id": " Co Wicklow"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Bilingual Customer Onboarding Specialist - Spanish and English"
#  },
#
#  "Ad_id": {
#    "id": " 5495329983"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Service Advisor - Dublin"
#  },
#
#  "Ad_id": {
#    "id": " 5495292899"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Call Centre Team Leader in Dublin Dublin"
#  },
#
#  "Ad_id": {
#    "id": " Ireland"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Care Wizard - German Speaker"
#  },
#
#  "Ad_id": {
#    "id": " 5495334588"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Contact Centre Customer Service Advisor - Dublin"
#  },
#
#  "Ad_id": {
#    "id": " 5495290817"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Specialist"
#  },
#
#  "Ad_id": {
#    "id": " 5495351459"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Dispatch Assistants"
#  },
#
#  "Ad_id": {
#    "id": " 5495290944"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Customer Support Advisors for Asian Markets (APAC)"
#  },
#
#  "Ad_id": {
#    "id": " 5495340510"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Jury Minder"
#  },
#
#  "Ad_id": {
#    "id": " 5495273747"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# },
# {
#
#  "Job_title": {
#    "title": "Dutch Candidates in beautiful Dublin or Galway! 28-45K"
#  },
#
#  "Ad_id": {
#    "id": " 5495279542"
#  },
#
#  "Country": {
#    "country": " Ireland"
#  },
#
#  "Sector": {
#    "sector": " Customer Service & Call Centre"
#  },
#
#  "Date": {
#    "date": " 2022-04-09"
#  },
#
#  "Risk_score": {
#    "risk": "0"
#  }
#
# }
# ]}

# %%
#import NLU queries from csv to array

queries_list=[]

keywords_arr=[]
weights_arr=[]

with open("nlu_keywords_queries.csv",newline='',encoding='utf-8') as q:
    queryReader=csv.reader(q)
    boolVal = 0
    for row in queryReader:
        queries_list.append(row)
        temp = str(row).split(',')
        while boolVal == 1:
                keywords_arr.append(temp[0])
                weights_arr.append(temp[1])

                boolVal = 0
        boolVal = 1
#print(len(queries_list))

# %%
#method to update risk score in data array
def updateRisk(tempFilePath,keywordWeight):
    with open (tempFilePath,"r") as qF:
        queryResult = json.load(qF)
    with open ('locanto_demo_formatted.json',"w") as lF:
        adList = json.load(lF)

    for result in queryResult['results']:
        adId = result.get('ad_id')
        riskNew = result['result_metadata'].get('confidence')
        for ad in adList['ads']:
            if ad['Ad_id'].get('id')==adId:
                riskOld=ad['Risk_score'].get('risk')
                riskUpdated=riskOld+riskNew*keywordWeight
                ad['Risk_score']['risk']=riskUpdated
                break

# %%
#iterate NLU queries with Watson Discovery and get confidence in result_metadata as risk score
query=1
while query < len(queries_list):
# while query < 2:
    response = discovery.query(
        project_id=PROJECT_ID,
        natural_language_query=queries_list[query][0],
        count=COLLECTION_SIZE,
        return_=['ad_id']).get_result()
    #print(json.dumps(response, indent=2))
    with tempfile.NamedTemporaryFile(suffix='.json') as tf:
        json.dumps(response, indent=2)
        tfPath = tf.name
        updateRisk(tfPath,queries_list[query][1])

# %%
### Watson Discovery NLU query sample ###
#risk score for a single NLU query
response = discovery.query(
        project_id=PROJECT_ID,
        natural_language_query=queries_list[1][0],
        count=COLLECTION_SIZE,
        return_=['ad_id']).get_result()
print(json.dumps(response, indent=2))
### output saved as 'sampleQR.json' ###
